# %%
# Assignment 1: Write a script that processes a list of temperature readings. If any temperature is above a certain threshold, print a warning.
temperature_readings = [25, 30, 35, 28, 40, 18]
threshold = 32

for temp in temperature_readings:
    if temp > threshold:
        print(f"Warning: Temperature {temp} exceeds the threshold of {threshold}°C.")
# Out:
# Warning: Temperature 35 exceeds the threshold of 32°C.
# Warning: Temperature 40 exceeds the threshold of 32°C.

# %%
# Assignment 2: Create a script that processes a dictionary of products, checking stock levels and generating restock alerts if necessary.
products = {
    "laptop": {"stock": 4, "min_required": 10},
    "smartphone": {"stock": 15, "min_required": 5},
    "tablet": {"stock": 2, "min_required": 8}
}

for product, details in products.items():
    stock = details["stock"]
    min_required = details["min_required"]
    if stock < min_required:
        print(f"Restock Alert: {product} stock is {stock}, below minimum required {min_required}.")
    else:
        print(f"{product} stock is sufficient ({stock}/{min_required}).")
# Out:
# Restock Alert: laptop stock is 4, below minimum required 10.
# smartphone stock is sufficient (15/5).
# Restock Alert: tablet stock is 2, below minimum required 8.
