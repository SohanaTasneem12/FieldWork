# %%
# Assignment 1: Create two variables, one holding a number and the other holding your name. Then print both.
# Write your code below:
age = 22
name = "Sohana"
print("Age: ", age, end="; ")
print("Name: ", name)
# Out:
# Age:  22; Name:  Sohana

# %%
# Assignment 2: Create variables of different types and use the type() function to check their types.
# Write your code below:
num = 10            # int
pi_value = 3.14159  # float
greeting = "Hello!" # str
is_active = False   # bool

print(type(num))
print(type(pi_value))
print(type(greeting))
print(type(is_active))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
# Assignment 3: Fix the bad variable name above and create three more variables with good naming practices.
# Write your code below:
fixed_name = 42
student_name = "Alice"
number_of_students = 25
is_enrolled = True
print(fixed_name, student_name, number_of_students, is_enrolled)
# Out:
# 42 Alice 25 True

# %%
# Assignment 4: Create a variable, assign it a value of one type, then reassign it to a different type and print both.
# Write your code below:
dynamic_var = "Dynamic typing in Python"
print(dynamic_var)

dynamic_var = 1001
print(dynamic_var)
# Out:
# Dynamic typing in Python
# 1001
