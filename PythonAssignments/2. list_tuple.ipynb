# %%
# Assignment 1: Create a 2D list representing a 3x3 matrix and perform operations like accessing, modifying, and iterating through it.
matrix_2D = [[10, 20, 30], [40, 50, 60], [70, 80, 90]]

print("Element at [1][2]:", matrix_2D[1][2])

matrix_2D[2][1] = 85
print("Modified matrix:", matrix_2D)

for row in matrix_2D:
    for element in row:
        print(element, end=" ")
    print()
# Out:
# Element at [1][2]: 60
# Modified matrix: [[10, 20, 30], [40, 50, 60], [70, 85, 90]]
# 10 20 30
# 40 50 60
# 70 85 90

# %%
# Assignment 2: Create a tuple with mixed data types and demonstrate its potential use cases in data structures like dictionaries.
student_info = ("Sohana", 12345, "Computer Science")
student_dict = {student_info: "Passed"}

print("Student Dictionary:", student_dict)
# Out:
# Student Dictionary: {('Sohana', 12345, 'Computer Science'): 'Passed'}

# %%
# Assignment 3: Create a list of tuples, where each tuple contains a student's name and their grade. Sort this list by grades.
students = [("Alice", 85), ("Bob", 92), ("Charlie", 78), ("David", 88)]
sorted_students = sorted(students, key=lambda x: x[1])

print("Sorted Students by Grades:", sorted_students)
# Out:
# Sorted Students by Grades: [('Charlie', 78), ('Alice', 85), ('David', 88), ('Bob', 92)]
